# %% [markdown]
# # Weather Prediction

# %% [markdown]
# ## Step 1: Install Dependencies
# Make sure you have these installed:

# %%
pip install pandas numpy scikit-learn matplotlib tensorflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\users\daniel lai\appdata\roaming\python\python313\site-packages (2.3.3)
# Requirement already satisfied: numpy in c:\users\daniel lai\appdata\roaming\python\python313\site-packages (2.2.4)
# Requirement already satisfied: scikit-learn in c:\users\daniel lai\appdata\roaming\python\python313\site-packages (1.7.2)
# Requirement already satisfied: matplotlib in c:\users\daniel lai\appdata\roaming\python\python313\site-packages (3.10.5)
# Requirement already satisfied: tensorflow in c:\users\daniel lai\appdata\roaming\python\python313\site-packages (2.20.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\daniel lai\appdata\roaming\python\python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\daniel lai\appdata\roaming\python\python313\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\daniel lai\appdata\roaming\python\python313\site-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\daniel lai\appdata\roaming\python\python313\site-packages (from scikit-learn) (1.16.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\daniel lai\appdata\roaming\python\python313\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\daniel lai\appdata\roaming\python\python313\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\daniel lai\appdata\roaming\python\python313\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\daniel lai\appdata\roaming\python\python313\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\daniel lai\appdata\roaming\python\python313\site-packages (from matplotlib) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\daniel lai\appdata\roaming\python\python313\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\daniel lai\appdata\roaming\python\python313\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\daniel lai\appdata\roaming\python\python313\site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\daniel lai\appdata\roaming\python\python313\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\daniel lai\appdata\roaming\python\python313\site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\daniel lai\appdata\roaming\python\python313\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\daniel lai\appdata\roaming\python\python313\site-packages (from tensorflow) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\daniel lai\appdata\roaming\python\python313\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\daniel lai\appdata\roaming\python\python313\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\daniel lai\appdata\roaming\python\python313\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\daniel lai\appdata\roaming\python\python313\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\daniel lai\appdata\roaming\python\python313\site-packages (from tensorflow) (6.32.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\daniel lai\appdata\roaming\python\python313\site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in c:\users\daniel lai\appdata\roaming\python\python313\site-packages (from tensorflow) (76.0.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\daniel lai\appdata\roaming\python\python313\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\daniel lai\appdata\roaming\python\python313\site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\daniel lai\appdata\roaming\python\python313\site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\daniel lai\appdata\roaming\python\python313\site-packages (from tensorflow) (1.17.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\daniel lai\appdata\roaming\python\python313\site-packages (from tensorflow) (1.75.1)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\users\daniel lai\appdata\roaming\python\python313\site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in c:\users\daniel lai\appdata\roaming\python\python313\site-packages (from tensorflow) (3.11.3)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\daniel lai\appdata\roaming\python\python313\site-packages (from tensorflow) (3.15.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\daniel lai\appdata\roaming\python\python313\site-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\daniel lai\appdata\roaming\python\python313\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\daniel lai\appdata\roaming\python\python313\site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\daniel lai\appdata\roaming\python\python313\site-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\daniel lai\appdata\roaming\python\python313\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.8.3)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\daniel lai\appdata\roaming\python\python313\site-packages (from tensorboard~=2.20.0->tensorflow) (3.9)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\daniel lai\appdata\roaming\python\python313\site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\daniel lai\appdata\roaming\python\python313\site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\daniel lai\appdata\roaming\python\python313\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in c:\users\daniel lai\appdata\roaming\python\python313\site-packages (from keras>=3.10.0->tensorflow) (14.2.0)
# Requirement already satisfied: namex in c:\users\daniel lai\appdata\roaming\python\python313\site-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\users\daniel lai\appdata\roaming\python\python313\site-packages (from keras>=3.10.0->tensorflow) (0.17.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\daniel lai\appdata\roaming\python\python313\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\daniel lai\appdata\roaming\python\python313\site-packages (from rich->keras>=3.10.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\daniel lai\appdata\roaming\python\python313\site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\daniel lai\appdata\roaming\python\python313\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Step 2: Import Libraries

# %%
# Step 2: Import Libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import joblib

# %% [markdown]
# ## Step 3: Load the Data

# %%
# Load the CSV
data = pd.read_csv("stlouis_weather.csv")

# %% [markdown]
# ## Step 4: Preprocess Data

# %%
# Drop rows with missing average temperature
data = data.dropna(subset=['TAVG'])

# Create a day-of-year feature to capture seasonality
data['DATE'] = pd.to_datetime(data['DATE'])
data['day_of_year'] = data['DATE'].dt.dayofyear

features = ['TMIN', 'TMAX', 'PRCP', 'AWND', 'day_of_year']
X = data[features].fillna(0).values # Fill missing values with 0
y = data['TAVG'].values # target

# %% [markdown]
# ## Step 5: Normalize Features

# %%
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Save the scaler
joblib.dump(scaler, 'scaler.save')
print("Scaler saved as 'scaler.save'")
# Out:
# Scaler saved as 'scaler.save'

# %% [markdown]
# ## Step 6: Split into Training and Test Sets

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)

print("X_train shape:", X_train.shape)
print("X_train type:", type(X_train))
# Out:
# X_train shape: (776, 5)
# X_train type: <class 'numpy.ndarray'>

# %% [markdown]
# ## Step 7: Build the Neural Network

# %%
## Step 7: Build the Neural Network
model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(32, activation='relu'),
    Dense(1) # regression output: predicted temperature
])

model.compile(optimizer='adam', loss='mse', metrics=['mae'])
# Out:
# C:\Users\Daniel Lai\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# ## Step 8: Train the Model

# %%
history = model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=16,
    validation_split=0.2
)
# Out:
# Epoch 1/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - loss: 4027.9084 - mae: 61.0448 - val_loss: 3426.1467 - val_mae: 55.6139
# Epoch 2/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3704.2419 - mae: 58.4044 - val_loss: 2903.1079 - val_mae: 50.9528
# Epoch 3/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2739.5962 - mae: 49.7469 - val_loss: 1678.3790 - val_mae: 38.0463
# Epoch 4/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1190.9709 - mae: 31.1655 - val_loss: 390.6597 - val_mae: 16.9019
# Epoch 5/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 228.8686 - mae: 12.5586 - val_loss: 120.8489 - val_mae: 9.1274
# Epoch 6/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 110.7869 - mae: 8.5938 - val_loss: 122.2421 - val_mae: 8.9816
# Epoch 7/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 105.5939 - mae: 8.4245 - val_loss: 115.2656 - val_mae: 8.8062
# Epoch 8/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 100.8709 - mae: 8.2624 - val_loss: 109.5065 - val_mae: 8.6086
# Epoch 9/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 95.7697 - mae: 7.9814 - val_loss: 104.4184 - val_mae: 8.3902
# Epoch 10/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 89.8042 - mae: 7.8306 - val_loss: 97.4361 - val_mae: 8.1217
# Epoch 11/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 82.3152 - mae: 7.4458 - val_loss: 90.2248 - val_mae: 7.8006
# Epoch 12/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 74.8501 - mae: 7.1123 - val_loss: 82.8247 - val_mae: 7.4346
# Epoch 13/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 66.4713 - mae: 6.6890 - val_loss: 72.0876 - val_mae: 7.0368
# Epoch 14/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 58.4162 - mae: 6.3190 - val_loss: 64.2982 - val_mae: 6.6082
# Epoch 15/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 50.8760 - mae: 5.8660 - val_loss: 55.0825 - val_mae: 6.1609
# Epoch 16/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 43.4382 - mae: 5.4094 - val_loss: 47.3339 - val_mae: 5.7151
# Epoch 17/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 36.6985 - mae: 4.9656 - val_loss: 40.1812 - val_mae: 5.2838
# Epoch 18/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 30.8720 - mae: 4.5592 - val_loss: 33.4382 - val_mae: 4.8731
# Epoch 19/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 25.6071 - mae: 4.1707 - val_loss: 30.0410 - val_mae: 4.4622
# Epoch 20/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 21.2027 - mae: 3.7476 - val_loss: 23.8767 - val_mae: 4.0517
# Epoch 21/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 17.6029 - mae: 3.3992 - val_loss: 19.9877 - val_mae: 3.6914
# Epoch 22/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 14.7058 - mae: 3.1100 - val_loss: 17.2749 - val_mae: 3.3893
# Epoch 23/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 12.2938 - mae: 2.8189 - val_loss: 14.6904 - val_mae: 3.1241
# Epoch 24/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 10.5832 - mae: 2.5794 - val_loss: 12.5441 - val_mae: 2.8810
# Epoch 25/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.2969 - mae: 2.3823 - val_loss: 11.1213 - val_mae: 2.6984
# Epoch 26/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 8.2673 - mae: 2.2301 - val_loss: 10.0148 - val_mae: 2.5436
# Epoch 27/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.5927 - mae: 2.1187 - val_loss: 9.5352 - val_mae: 2.4694
# Epoch 28/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.0893 - mae: 2.0351 - val_loss: 8.6408 - val_mae: 2.3272
# Epoch 29/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.6816 - mae: 1.9682 - val_loss: 8.2241 - val_mae: 2.2555
# Epoch 30/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.4118 - mae: 1.9029 - val_loss: 7.6927 - val_mae: 2.1682
# Epoch 31/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.2171 - mae: 1.8761 - val_loss: 7.4506 - val_mae: 2.1229
# Epoch 32/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.0085 - mae: 1.8353 - val_loss: 7.2771 - val_mae: 2.0857
# Epoch 33/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.8462 - mae: 1.8061 - val_loss: 7.1948 - val_mae: 2.0663
# Epoch 34/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.7764 - mae: 1.7957 - val_loss: 6.8111 - val_mae: 2.0100
# Epoch 35/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.6743 - mae: 1.7724 - val_loss: 6.6236 - val_mae: 1.9769
# Epoch 36/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 5.5525 - mae: 1.7505 - val_loss: 6.5507 - val_mae: 1.9571
# Epoch 37/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.4263 - mae: 1.7237 - val_loss: 6.4357 - val_mae: 1.9337
# Epoch 38/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.3556 - mae: 1.7097 - val_loss: 6.4862 - val_mae: 1.9353
# Epoch 39/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.3436 - mae: 1.7001 - val_loss: 6.3289 - val_mae: 1.9066
# Epoch 40/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.2280 - mae: 1.6868 - val_loss: 6.1265 - val_mae: 1.8748
# Epoch 41/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.2241 - mae: 1.6837 - val_loss: 6.0198 - val_mae: 1.8596
# Epoch 42/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.1298 - mae: 1.6793 - val_loss: 6.3352 - val_mae: 1.9124
# Epoch 43/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.1123 - mae: 1.6663 - val_loss: 5.8942 - val_mae: 1.8330
# Epoch 44/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 5.0481 - mae: 1.6619 - val_loss: 5.9103 - val_mae: 1.8277
# Epoch 45/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.0747 - mae: 1.6719 - val_loss: 5.8051 - val_mae: 1.8142
# Epoch 46/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.9985 - mae: 1.6556 - val_loss: 5.7741 - val_mae: 1.8034
# Epoch 47/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.9483 - mae: 1.6352 - val_loss: 5.7584 - val_mae: 1.7991
# Epoch 48/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.9015 - mae: 1.6420 - val_loss: 5.7125 - val_mae: 1.7997
# Epoch 49/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.8832 - mae: 1.6273 - val_loss: 5.6944 - val_mae: 1.7835
# Epoch 50/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.8832 - mae: 1.6325 - val_loss: 5.6280 - val_mae: 1.7788

# %% [markdown]
# ## Step 9: Evaluate the Model

# %%
# Evaluate using Keras
loss, mae = model.evaluate(X_test, y_test)
print(f"Test Loss (MSE): {loss:.3f}, Mean Absolute Error: {mae:.3f}")

# Predict using model
y_pred = model.predict(X_test).flatten()

# Compute R² score
r2 = r2_score(y_test, y_pred)
print(f"R² score: {r2:.3f}")
print(f"Model Accuracy: {r2*100:.2f}%")
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.9633 - mae: 1.6067
# Test Loss (MSE): 4.963, Mean Absolute Error: 1.607
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# R² score: 0.987
# Model Accuracy: 98.66%

# %% [markdown]
# ## Step 10: Plot Training History

# %%
plt.figure(figsize=(8,5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss (MSE)')
plt.title('Model Training Progress')
plt.legend()
plt.show()

# %% [markdown]
# ## Step 11: Plot Predicted vs Actual

# %%
plt.figure(figsize=(6,6))
plt.scatter(y_test, y_pred, alpha=0.5)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')
plt.xlabel("Actual Temperature (°C)")
plt.ylabel("Predicted Temperature (°C)")
plt.title("Predicted vs Actual Temperatures")
plt.show()

# %% [markdown]
# ## Step 12: Make Predictions

# %%
predictions = model.predict(X_test)

# Flatten predictions to 1D array
predictions_flat = predictions.flatten()

# Create a DataFrame
results_df = pd.DataFrame({
    "Predicted": predictions_flat,
    "Actual": y_test
})

# Show first 10 rows
print(results_df.head(10))
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
#    Predicted  Actual
# 0  81.650505    81.0
# 1  68.081856    67.0
# 2  43.808083    44.0
# 3  64.721336    64.0
# 4  39.433689    41.0
# 5  86.580711    87.0
# 6  52.180664    49.0
# 7  69.202629    70.0
# 8  55.281693    53.0
# 9  79.919334    79.0

# %% [markdown]
# ## Step 13: Save the Model

# %%
model.save('stlouis_temperature_predictor.keras')
print("Model saved as 'stlouis_temperature_predictor.keras'")
# Out:
# Model saved as 'stlouis_temperature_predictor.keras'
